# %% [markdown]
# ### Upload a CSV file
#
# Run the following cell to open a file upload widget. Select your CSV file and click 'Open'. The file will be uploaded to the Colab environment.

# %%
#the cells here are ordered and do specific jobs
#what cell 0 this one does is introduction to the concept of file upload
#cell 1 reads the file and outputs the column, shape, head
#cell 2 will do the heavy lifting of cleaning the data starting with removing rows with empty data on a particular necessary column usign dropna
#then dropping irrelivant columns, fixing inconsistent text and also standardizing it, also fixing the data type and remove duplicate values also
#cell 3 create a simple ML model with a target
#cell 4 import an algorithm(for this case i choose rf model)
#cell 5 splitt up training and test data
#cell 6 import accurancy score and precision score, break down the data and look at it


# here is the code to upload files by the way it's that simple
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9ab26c96-1418-4a6d-bb1d-2dd5a28db44f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9ab26c96-1418-4a6d-bb1d-2dd5a28db44f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#cell 1, look at our data more clearly
import pandas as pd

file_name = 'matches.csv'
matches_df = pd.read_csv(file_name)
print(f"Successfully loaded '{file_name}' into a DataFrame. Here are the first 5 rows:")
#display(matches_df.head(2))
print(matches_df.columns)
print(matches_df.shape)
print(matches_df[matches_df['team'] == "Liverpool"])
# Out:
# Successfully loaded 'matches.csv' into a DataFrame. Here are the first 5 rows:
#    Unnamed: 0        date   time            comp        round  day venue  \
# 0           1  2021-08-15  16:30  Premier League  Matchweek 1  Sun  Away
# 1           2  2021-08-21  15:00  Premier League  Matchweek 2  Sat  Home
#
#   result   gf   ga  ...  match report  notes    sh  sot  dist   fk   pk pkatt  \
# 0      L  0.0  1.0  ...  Match Report    NaN  18.0  4.0  16.9  1.0  0.0   0.0
# 1      W  5.0  0.0  ...  Match Report    NaN  16.0  4.0  17.3  1.0  0.0   0.0
#
#   season             team
# 0   2022  Manchester City
# 1   2022  Manchester City
#
# [2 rows x 28 columns]
# Index(['Unnamed: 0', 'date', 'time', 'comp', 'round', 'day', 'venue', 'result',
#        'gf', 'ga', 'opponent', 'xg', 'xga', 'poss', 'attendance', 'captain',
#        'formation', 'referee', 'match report', 'notes', 'sh', 'sot', 'dist',
#        'fk', 'pk', 'pkatt', 'season', 'team'],
#       dtype='object')
# (1389, 28)

# %%
#cell 2
#practice to clean the data
#1. remove redundent rows and columns
#matches_df = matches_df.dropna(subset = ["attendance"])
#matches_df = matches_df.drop(columns = ["captain"])
#2. standardize wording
matches_df['venue'] = matches_df['venue'].str.capitalize()
matches_df['bro'] =  matches_df['venue'].replace({'United States': 'USA'})
print(matches_df.shape)
#3. change some data columns into numbers
# Out:
# (1389, 29)
